# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad

def e_thermal_sampling(size):
    # Generate random numbers from a uniform distribution between 0 and 1
    u = np.random.uniform(size=size)

    # Apply the inverse transform to obtain the thermal samples
    e = np.sqrt(u)

    return e

# Parameters
sample_size = 100000

# Sample from the thermal distribution
samples = e_thermal_sampling(sample_size)

e = np.linspace(0,1,100000)
P_e = 2 * e

# Plot histogram of the normalized samples
plt.hist(samples, bins='auto', density=True)
plt.plot(e, P_e, 'r-', label='P(e)=2*e')
plt.xlabel('Samples')
plt.ylabel('Probability Density')
plt.title('Normalized Thermal Distribution Histogram')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [0.98433482 0.77158783 0.84068031 ... 0.59494923 0.41398092 0.54348086]
